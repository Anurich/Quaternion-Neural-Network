# %%
import tensorflow as tf
import numpy as np
from scipy import misc

# %%
class convolution:
    
    def __init__(self,in_channel,ot_channel,kernel_size,strides):
        
        self.in_channel = in_channel//4
        self.ot_channel = ot_channel//4
        self.weight_size = [self.ot_channel,self.in_channel,kernel_size,kernel_size]
        self.kernel  = (kernel_size,kernel_size)
        self.kernel_size  =  kernel_size
        self.stride  =  strides
             
        #initialize the weights
        self.glorat_normal =  np.sqrt(2/(self.in_channel+self.ot_channel))
        self.r_weight  =  tf.random_normal(self.weight_size,stddev=self.glorat_normal)
        self.i_weight  = tf.random_normal(self.weight_size,stddev=self.glorat_normal)
        self.j_weight  =  tf.random_normal(self.weight_size,stddev=self.glorat_normal)
        self.k_weight  =  tf.random_normal(self.weight_size,stddev=self.glorat_normal)
        
        
        
     
        
    def conv2D(self,x):
        
        qr_kernelR = tf.concat([self.r_weight,-self.i_weight,-self.j_weight,-self.k_weight],axis=1)
        qr_kerneli = tf.concat([self.i_weight,self.r_weight,-self.j_weight,self.k_weight],axis=1)
        qr_kernelj = tf.concat([self.j_weight,self.i_weight,self.r_weight,-self.k_weight],axis=1)
        qr_kernelk = tf.concat([self.k_weight,-self.i_weight,self.j_weight,self.r_weight],axis=1)
        
        weight =tf.concat([qr_kernelR,qr_kerneli,qr_kernelj,qr_kernelk],axis=0)
        
        
        weight  = tf.reshape(weight,(weight.shape[3],weight.shape[2],weight.shape[1],weight.shape[0]))
        
        weight  = tf.Variable(weight)
        
        
        Z = tf.nn.conv2d(x,weight,strides=[1,2,2,1],padding="SAME")
        output  = tf.nn.tanh(Z)
        return output
    
    
    def calculateOutputShape(self,input_shape,stride,kernel_size):
        
        x =  (input_shape -1)*stride +2
        return x.value

    
    def conv2DTranspose(self,x):
        
        qr_kernelR = tf.concat([self.r_weight,-self.i_weight,-self.j_weight,-self.k_weight],axis=1)
        qr_kerneli = tf.concat([self.i_weight,self.r_weight,-self.j_weight,self.k_weight],axis=1)
        qr_kernelj = tf.concat([self.j_weight,self.i_weight,self.r_weight,-self.k_weight],axis=1)
        qr_kernelk = tf.concat([self.k_weight,-self.i_weight,self.j_weight,self.r_weight],axis=1)
        
        weight = tf.concat([qr_kernelR,qr_kerneli,qr_kernelj,qr_kernelk],axis=0)
        weight  = tf.reshape(weight,(weight.shape[3],weight.shape[2],weight.shape[0],weight.shape[1]))
        
        weight  =  tf.Variable(weight)
        
        #H1(input_size)*stride  if padding == SAME
    
        H1  = [1,self.calculateOutputShape(x.shape[1],self.stride,self.kernel_size),self.calculateOutputShape(x.shape[2],self.stride,self.kernel_size),weight.shape[2].value]
    
        Z = tf.nn.conv2d_transpose(x,weight,strides=[1,2,2,1],output_shape=H1,padding="SAME")
        output  = tf.nn.tanh(Z)
     
        return output
    
    
    @staticmethod
    def forwardModel(x):
        #encoder
        cnv = convolution(4,32,3,2)
        output1  = cnv.conv2D(x)
        
      
        cnv =  convolution(32,40,3,2)
        output2 = cnv.conv2D(output1)
       
        #decoder
        cnv =  convolution(40,32,3,2)
        output3 = cnv.conv2DTranspose(output2)
      
        cnv =  convolution(32,4,3,2)
        y = cnv.conv2DTranspose(output3)
       
        return y

# %%
from PIL import Image
size = 256

train_original = Image.open("kodim01.png")
train_original = train_original.resize((size,size))
train_original = train_original.convert('L')

train = np.zeros((size,size,4))
train[:,:,0]= np.zeros(size)
train[:,:,1]= train_original
train[:,:,2]= train_original
train[:,:,3]= train_original
train = np.expand_dims(train,0)
train = train / float(255)
train = train.astype('float32')


test_original = Image.open("kodim04.png")
test_original = test_original.resize((size,size))
test_original = np.asarray(test_original)

test = np.zeros((size,size,4))
test[:,:,0]= np.zeros(size)
test[:,:,1]= npim[:,:,0]
test[:,:,2]= npim[:,:,1]
test[:,:,3]= npim[:,:,2]
test = np.expand_dims(test,0)
test =  test / float(255)
test = test.astype('float32')


X  = tf.placeholder('float32',[None,train.shape[1],train.shape[2],train.shape[3]])
Y  = tf.placeholder('float32',[None,train.shape[1],train.shape[2],train.shape[3]])
                             
train.dtype
# Out:
# dtype('float32')

# %%
# forward output 
pred = convolution.forwardModel(X)

#MSE
loss  =  tf.losses.mean_squared_error(Y,pred)
optimizer =  tf.train.AdamOptimizer(learning_rate=0.01).minimize(loss)

# gradient,variable  = zip(*optimizer.compute_gradients(loss))

# optimizer.apply_gradients()

# %%
init =  tf.global_variables_initializer()
saver = tf.train.Saver()
y_predict = []
with tf.Session() as sess:
    sess.run(init)
    for i in range(10000):
        loss_value,opt = sess.run([loss,optimizer],feed_dict={X:train,Y:train})
        if i % 5000 ==0:
            print(loss_value)
#     train_output = sess.run(pred,feed_dict={X:train})
    test_output =  sess.run(pred,feed_dict={X:test})

plt.imshow(np.squeeze(train_output,0)[:,:,1:])
plt.show()
plt.imshow(train_original)
plt.show()
plt.imshow(np.squeeze(test_output,0)[:,:,1:])
plt.show()
plt.imshow(test_original)
plt.show()
# Out:
# 0.82756174
# 0.101509884
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(np.squeeze(output,0))
plt.show()
plt.imshow()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-166-f26a711273b6> in <module>()
#       1 plt.imshow(np.squeeze(output,0))
#       2 plt.show()
# ----> 3 plt.imshow()
#       4 plt.show()
#
# TypeError: imshow() missing 1 required positional argument: 'X'

# %%
im = Image.open("feature_img_pt_1.jpg")
size = 256
im = im.resize((size,size))

npim = np.asarray(im)
qim = np.zeros((size,size,4))
qim[:,:,0]=np.zeros(size)
qim[:,:,1]= npim[:,:,0]
qim[:,:,2]= npim[:,:,1]
qim[:,:,3]= npim[:,:,2]
qim = np.expand_dims(qim,0)
cim = qim.astype('float')

# %%
import matplotlib.pyplot as plt



plt.imshow(output)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
output.shape
# Out:
# (256, 256, 3)

# %%
# Varaible is the weights and we can access the each layer weight 
'''
[[ 0.14778088 -0.4813323   1.1383988  ...  1.0975109   0.34871793
    -1.077853  ]
   [ 0.44553557  1.2174044   1.0233548  ...  1.4499682  -0.938326
    -1.4166042 ]
   [-0.16231556  1.0602733  -0.42740405 ...  1.0800638  -1.3351275
     1.5718327 ]
   [-1.0038142  -0.89527065  0.40110257 ...  2.2186792   1.5408912
     0.24910045]]

'''
    
# 4 layers 
# if we have to perform the custom multiplication using the hamilton we need 
# use the method inside the apply_gradient class in which for us the main function is _apply_dense() which 
# basically modify the weight and perform the backward multiplication between the filter and image
# Out:
# [[[[ 0.14778088 -0.4813323   1.1383988  ...  1.0975109   0.34871793
#     -1.077853  ]
#    [ 0.44553557  1.2174044   1.0233548  ...  1.4499682  -0.938326
#     -1.4166042 ]
#    [-0.16231556  1.0602733  -0.42740405 ...  1.0800638  -1.3351275
#      1.5718327 ]
#    [-1.0038142  -0.89527065  0.40110257 ...  2.2186792   1.5408912
#      0.24910045]]
#
#   [[ 0.8401468   0.5350972  -0.15447979 ... -0.525636   -1.7256913
#     -0.42007652]
#    [ 1.0507425  -0.3261639   0.56206733 ... -0.27306485 -1.8532736
#     -0.12813774]
#    [ 0.26697057  2.0988026  -0.3933203  ... -1.7569062  -0.8322582
#      0.97428894]
#    [-0.8964062   0.5859836   0.13358676 ...  1.4707788  -0.39980078
#      1.4045217 ]]
#
#   [[ 0.6167577  -1.0992191  -0.7475692  ... -0.2475005  -1.5465685
#      2.067803  ]
#    [ 0.82635885 -1.3977545   1.1936562  ... -1.0975109  -0.34871793
#      1.077853  ]
#    [-0.44553557 -1.2174044  -1.0233548  ...  1.4499682  -0.938326
#      1.4166042 ]
#    [ 0.16231556 -1.0602733   0.42740405 ...  1.0800638  -1.3351275
#      1.5718327 ]]]
#
#
#  [[[-1.0038142  -0.89527065  0.40110257 ...  1.5763506   1.5408912
#      0.24910045]
#    [ 0.8401468   0.5350972  -0.15447979 ...  0.6833993   0.50340265
#     -1.5790482 ]
#    [ 0.38230208  0.28430817  0.56206733 ... -1.7874435   1.1901672
#      2.1137042 ]
#    [-0.6859237  -1.2127135  -1.1731223  ... -0.58177644  1.2194513
#     -0.54106474]]
#
#   [[-0.0667314  -0.18030001  0.03104888 ...  0.522604    1.4747977
#      0.05144512]
#    [-0.88360184 -0.18360473  0.02744128 ...  0.2475005   1.5465685
#     -2.067803  ]
#    [-0.21119006 -1.0424094  -0.21858418 ...  1.0975109   0.34871793
#     -1.077853  ]
#    [ 0.44553557  1.2174044   1.0233548  ...  0.3366911  -0.44722193
#     -1.4166042 ]]
#
#   [[-0.16231556  1.0602733  -0.42740405 ... -0.4865521  -0.6761882
#      0.47254318]
#    [ 0.2925308  -0.96290654  1.4595623  ... -2.2186792   0.20043059
#     -0.48365813]
#    [-0.06934355  1.4546198   1.0990524  ...  0.525636    1.7256913
#      0.42007652]
#    [-1.0507425   0.3261639  -0.49352732 ...  0.27306485  1.8532736
#      0.12813774]]]
#
#
#  [[[-0.26697057 -2.0988026   0.3933203  ... -0.38627547 -0.1790509
#      1.3652071 ]
#    [-0.7224232  -0.5859836  -0.13358676 ...  0.10449311  0.9838218
#      0.03126701]
#    [ 1.4625366  -0.73277396 -1.0164757  ... -0.2475005  -1.5465685
#      2.067803  ]
#    [-0.537513   -0.03797271 -1.0975109  ...  1.1383988  -1.8062892
#     -0.37099606]]
#
#   [[-0.24859941  0.65618396 -0.36277846 ... -1.4499682   0.938326
#     -0.28019622]
#    [-0.7601038   0.12196116 -1.1361953  ... -1.0800638   1.3351275
#     -1.5718327 ]
#    [ 1.0038142   0.89527065 -0.40110257 ...  2.2186792  -1.5408912
#     -0.24910045]
#    [-0.8401468  -0.5350972   0.15447979 ... -0.525636   -1.7256913
#     -0.42007652]]
#
#   [[ 1.0507425  -0.3261639  -0.56206733 ... -0.27306485 -1.8532736
#     -0.12813774]
#    [ 0.26697057  2.0988026  -0.3933203  ...  0.09855554 -1.9839511
#      0.7372218 ]
#    [-0.48304376  0.5859836   0.13358676 ... -1.3066341  -1.3321116
#      0.37067637]
#    [ 0.01278521 -0.34200644  0.2475005  ... -0.7475692  -0.31728542
#      0.60168356]]]]

# %%
# im = Image.open("kodim01.png")
# size = (256, 256)
# im = im.resize(size)

# def rgb2gray(rgb):
#     gray = np.dot(rgb[...,:3], [0.299, 0.587, 0.114])
#     return np.repeat(gray[:, :, np.newaxis], 3, axis=2)


# img =  rgb2gray(misc.imread("kodim01.png"))/255
# train  = img.astype(np.float32)




      
      
#          # Add a 0 as real component if quaternions (padding)
# npad  = ((0, 0), (0, 0), (1, 0))
# train = np.pad(train, pad_width=npad, mode='constant', constant_values=0)
# print(train.shape)
# # Channel first
# train = np.transpose(train, (1,0,2))
# # Add batch_size dim
# train = np.reshape(train, (1, train.shape[0], train.shape[1], train.shape[2]))
# print(train.shape)
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   # Remove the CWD from sys.path while we load stuff.
# (512, 768, 4)
# (1, 768, 512, 4)
# <dtype: 'float32_ref'>
# <dtype: 'float32_ref'>
# [1, <tf.Variable 'Variable_59:0' shape=() dtype=int32_ref>, <tf.Variable 'Variable_60:0' shape=() dtype=int32_ref>, Dimension(40)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-f1fb35a6baa4> in <module>()
#      35
#      36 cnv =  convolution(40,32,3,2,output)
# ---> 37 output = cnv.conv2DTranspose()
#
# <ipython-input-192-39543a1d15a7> in conv2DTranspose(self)
#      73
#      74
# ---> 75         Z = tf.nn.conv2d_transpose(self.input,weight,strides=[1,2,2,1],output_shape=H1,padding="SAME")
#      76         output  = tf.nn.relu(Z)
#      77
#
# /opt/DL/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in conv2d_transpose(value, filter, output_shape, strides, padding, data_format, name)
#    1239             "output_shape does not match filter's output channels, "
#    1240             "{} != {}".format(output_shape[axis],
# -> 1241                               filter.get_shape()[2]))
#    1242
#    1243     if padding != "VALID" and padding != "SAME":
#
# ValueError: output_shape does not match filter's output channels, 40 != 32

# %%
x = tf.Variable(0.5)
y = x*x
opt = tf.train.AdagradOptimizer(0.1)
grads = opt.compute_gradients(y)

grad_placeholder = [(tf.placeholder("float", shape=grad[1].get_shape())), grad[1] for grad in grads]
# Out:
#   File "<ipython-input-10-e5c04829d839>", line 6
#     grad_placeholder = [(tf.placeholder("float", shape=grad[1].get_shape())), grad[1] for grad in grads]
#                                                                                         ^
# SyntaxError: invalid syntax

# %%
apply_placeholder_op = opt.apply_gradients(grad_placeholder)
transform_grads = [(function1(grad[0]), grad[1]) for grad in grads]
apply_transform_op = opt.apply_gradients(transform_grads)
